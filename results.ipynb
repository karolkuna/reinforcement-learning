# %%
from visualisation import *

# %% [markdown]
# Results are not final. Proper averages, variance, and confidence will be added later. Currently, best result out of several runs was selected for each method.

# %% [markdown]
# # Pendulum-v0

# %% [markdown]
# Batch size=256, discount factor=0.9, training updates per step=10, epsilon greedy exploration (quadratic epsilon decay, 256-step motor babbling phase)

# %%
experiments = [
    ("experiment_ddpg_Pendulum-v0_1493212944", "DDPG"),
    ("experiment_deepmlac_Pendulum-v0_1493230512", "1-step DeepMLAC"),
    ("experiment_deepmlac_Pendulum-v0_1493233507", "3-step DeepMLAC(td=0.5)"),
    ("experiment_deepmlac_Pendulum-v0_1493232513", "5-step DeepMLAC(td=0.25)"),
]
visualise_cumulative_reward(experiments, "Pendulum-v0")

# %% [markdown]
# ![Pendulum](images/pendulum.gif "Pendulum")

# %% [markdown]
# #  MountainCarContinuous-v0

# %% [markdown]
# Batch size=256, discount factor=0.99, training updates per step=10, one exploratory episode with Ornstein–Uhlenbeck noise, no exploration after that

# %%
experiments = [
    ("experiment_ddpg_MountainCarContinuous-v0_1493233805", "DDPG"),
    ("experiment_deepmlac_MountainCarContinuous-v0_1493226685", "1-step DeepMLAC"),
    ("experiment_deepmlac_MountainCarContinuous-v0_1493241812", "3-step DeepMLAC(0.5)"),
]
visualise_episode_reward(experiments, "MountainCarContinuous-v0", 1)
visualise_cumulative_reward(experiments, "MountainCarContinuous-v0", 256)
visualise_episode_duration(experiments, "MountainCarContinuous-v0", 1)

# %% [markdown]
# ![MountainCarContinuous](images/mountaincarcontinuous.gif "MountainCarContinuous")

# %% [markdown]
# #  InvertedPendulum-v1

# %%
experiments = [
]
